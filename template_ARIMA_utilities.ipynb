# %% [markdown]
# Example : https://medium.com/@josemarcialportilla/using-python-and-auto-arima-to-forecast-seasonal-time-series-90877adff03c

# %%
# load packages
import pandas as pd
# %matplotlib inline
from matplotlib import pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')

# %%
data = pd.read_csv('IPG2211A2N.csv', index_col = 0)
data.head()
# Out:
#             IPG2211A2N
# DATE
# 1939-01-01      3.3842
# 1939-02-01      3.4100
# 1939-03-01      3.4875
# 1939-04-01      3.5133
# 1939-05-01      3.5133

# %%
# put index
data.index = pd.to_datetime(data.index)

# %%
# column rename
data.columns = {'Energy Production'}

# %%
data.plot(title = 'Energy Production', color = 'b')

# %%
# decomposition
#from plotly.plotly import plot_mpl
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
result = seasonal_decompose(data, model='multiplicative')
result.plot()

# %%
from pyramid.arima import auto_arima
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-24-4e35d3e40b01> in <module>()
# ----> 1 from pyramid.arima import auto_arima
#
# ImportError: No module named 'pyramid.arima'
