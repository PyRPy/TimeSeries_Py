# %%
# A Multivariate Time Series Guide to Forecasting and Modeling

# %%
#import required packages
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from math import sqrt
from sklearn.metrics import mean_squared_error

import warnings
warnings.filterwarnings("ignore")

# %%
#read the data
df = pd.read_csv("AirQualityUCI2.csv")

#check the dtypes
df.dtypes
# Out:
# Date              object
# Time              object
# CO(GT)           float64
# PT08.S1(CO)      float64
# NMHC(GT)         float64
# C6H6(GT)         float64
# PT08.S2(NMHC)    float64
# NOx(GT)          float64
# PT08.S3(NOx)     float64
# NO2(GT)          float64
# PT08.S4(NO2)     float64
# PT08.S5(O3)      float64
# T                float64
# RH               float64
# AH               float64
# Unnamed: 15      float64
# Unnamed: 16      float64
# dtype: object

# %%
df.head()
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  3/10/2004  18:00:00     2.6       1360.0     150.0      11.9
# 1  3/10/2004  19:00:00     2.0       1292.0     112.0       9.4
# 2  3/10/2004  20:00:00     2.2       1402.0      88.0       9.0
# 3  3/10/2004  21:00:00     2.2       1376.0      80.0       9.2
# 4  3/10/2004  22:00:00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH  Unnamed: 15  Unnamed: 16
# 0  13.6  48.9  0.7578          NaN          NaN
# 1  13.3  47.7  0.7255          NaN          NaN
# 2  11.9  54.0  0.7502          NaN          NaN
# 3  11.0  60.0  0.7867          NaN          NaN
# 4  11.2  59.6  0.7888          NaN          NaN

# %%
# convert index to have datetime
df['Date_Time'] = df.Date + ' ' + df.Time
df.head()
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  3/10/2004  18:00:00     2.6       1360.0     150.0      11.9
# 1  3/10/2004  19:00:00     2.0       1292.0     112.0       9.4
# 2  3/10/2004  20:00:00     2.2       1402.0      88.0       9.0
# 3  3/10/2004  21:00:00     2.2       1376.0      80.0       9.2
# 4  3/10/2004  22:00:00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH  Unnamed: 15  Unnamed: 16           Date_Time
# 0  13.6  48.9  0.7578          NaN          NaN  3/10/2004 18:00:00
# 1  13.3  47.7  0.7255          NaN          NaN  3/10/2004 19:00:00
# 2  11.9  54.0  0.7502          NaN          NaN  3/10/2004 20:00:00
# 3  11.0  60.0  0.7867          NaN          NaN  3/10/2004 21:00:00
# 4  11.2  59.6  0.7888          NaN          NaN  3/10/2004 22:00:00

# %%
df['Date_Time'] = pd.to_datetime(df.Date_Time , format = '%m/%d/%Y %H:%M:%S')

# %%
data = df.drop(['Date', 'Time', 'Date_Time'], axis=1)

data.index = df.Date_Time

# %%
data.head()
# Out:
#                      CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# Date_Time
# 2004-03-10 18:00:00     2.6       1360.0     150.0      11.9         1046.0
# 2004-03-10 19:00:00     2.0       1292.0     112.0       9.4          955.0
# 2004-03-10 20:00:00     2.2       1402.0      88.0       9.0          939.0
# 2004-03-10 21:00:00     2.2       1376.0      80.0       9.2          948.0
# 2004-03-10 22:00:00     1.6       1272.0      51.0       6.5          836.0
#
#                      NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# Date_Time
# 2004-03-10 18:00:00    166.0        1056.0    113.0        1692.0
# 2004-03-10 19:00:00    103.0        1174.0     92.0        1559.0
# 2004-03-10 20:00:00    131.0        1140.0    114.0        1555.0
# 2004-03-10 21:00:00    172.0        1092.0    122.0        1584.0
# 2004-03-10 22:00:00    131.0        1205.0    116.0        1490.0
#
#                      PT08.S5(O3)     T    RH      AH  Unnamed: 15  Unnamed: 16
# Date_Time
# 2004-03-10 18:00:00       1268.0  13.6  48.9  0.7578          NaN          NaN
# 2004-03-10 19:00:00        972.0  13.3  47.7  0.7255          NaN          NaN
# 2004-03-10 20:00:00       1074.0  11.9  54.0  0.7502          NaN          NaN
# 2004-03-10 21:00:00       1203.0  11.0  60.0  0.7867          NaN          NaN
# 2004-03-10 22:00:00       1110.0  11.2  59.6  0.7888          NaN          NaN

# %%
data.columns
# Out:
# Index(['CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)', 'PT08.S2(NMHC)',
#        'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)', 'PT08.S5(O3)',
#        'T', 'RH', 'AH', 'Unnamed: 15', 'Unnamed: 16'],
#       dtype='object')

# %%
data = data.drop(['Unnamed: 15', 'Unnamed: 16'], axis = 1)

# %%
data = data.dropna()

# %%
# plot the data
data.plot(subplots = True, figsize = (12, 16))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000017E0911A898>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000017E091AC588>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000017E091CFA20>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000017E08D77F60>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000017E08DA9518>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000017E08DA9550>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000017E08E05048>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000017E08E2C5C0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000017E08E55B38>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000017E08E880F0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000017E08EAE668>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000017E08ED9BE0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000017E08F0A198>],
#       dtype=object)

# %%
#checking stationarity
from statsmodels.tsa.vector_ar.vecm import coint_johansen
#since the test works for only 12 variables, I have randomly dropped
#in the next iteration, I would drop another and check the eigenvalues
johan_test_temp = data.drop([ 'CO(GT)'], axis=1)
coint_johansen(johan_test_temp,-1,1).eig
# Out:
# array([1.85137431e-01, 1.49562379e-01, 9.98466990e-02, 9.15622257e-02,
#        6.59920501e-02, 5.02055763e-02, 4.01484678e-02, 3.35580944e-02,
#        1.84178447e-02, 1.50158406e-02, 4.14847921e-03, 7.21944108e-05])

# %%
#creating the train and validation set
train = data[:int(0.8*(len(data)))]
valid = data[int(0.8*(len(data))):]

#fit the model
from statsmodels.tsa.vector_ar.var_model import VAR

model = VAR(endog=train)
model_fit = model.fit()

# %%
train.head()
# Out:
#                      CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# Date_Time
# 2004-03-10 18:00:00     2.6       1360.0     150.0      11.9         1046.0
# 2004-03-10 19:00:00     2.0       1292.0     112.0       9.4          955.0
# 2004-03-10 20:00:00     2.2       1402.0      88.0       9.0          939.0
# 2004-03-10 21:00:00     2.2       1376.0      80.0       9.2          948.0
# 2004-03-10 22:00:00     1.6       1272.0      51.0       6.5          836.0
#
#                      NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# Date_Time
# 2004-03-10 18:00:00    166.0        1056.0    113.0        1692.0
# 2004-03-10 19:00:00    103.0        1174.0     92.0        1559.0
# 2004-03-10 20:00:00    131.0        1140.0    114.0        1555.0
# 2004-03-10 21:00:00    172.0        1092.0    122.0        1584.0
# 2004-03-10 22:00:00    131.0        1205.0    116.0        1490.0
#
#                      PT08.S5(O3)     T    RH      AH
# Date_Time
# 2004-03-10 18:00:00       1268.0  13.6  48.9  0.7578
# 2004-03-10 19:00:00        972.0  13.3  47.7  0.7255
# 2004-03-10 20:00:00       1074.0  11.9  54.0  0.7502
# 2004-03-10 21:00:00       1203.0  11.0  60.0  0.7867
# 2004-03-10 22:00:00       1110.0  11.2  59.6  0.7888

# %%
# make prediction on validation
prediction = model_fit.forecast(model_fit.y, steps=len(valid))

# %%
#converting predictions to dataframe
pred = pd.DataFrame(index=range(0,len(prediction)),columns=[cols])
for j in range(0,13):
    for i in range(0, len(prediction)):
       pred.iloc[i][j] = prediction[i][j]

#check rmse
for i in cols:
    print('rmse value for', i, 'is : ', sqrt(mean_squared_error(pred[i], valid[i])))
# Out:
# rmse value for CO(GT) is :  54.09344905990406
# rmse value for PT08.S1(CO) is :  337.85729186053834
# rmse value for NMHC(GT) is :  55.214852833503336
# rmse value for C6H6(GT) is :  44.23011773032389
# rmse value for PT08.S2(NMHC) is :  350.70592156378075
# rmse value for NOx(GT) is :  261.3296362654395
# rmse value for PT08.S3(NOx) is :  322.0136519697846
# rmse value for NO2(GT) is :  121.0689985449062
# rmse value for PT08.S4(NO2) is :  549.2236083304895
# rmse value for PT08.S5(O3) is :  504.38154718473953
# rmse value for T is :  45.78117896705036
# rmse value for RH is :  54.77254351524961
# rmse value for AH is :  42.084517905597764

# %%
#make final predictions
model = VAR(endog=data)
model_fit = model.fit()
yhat = model_fit.forecast(model_fit.y, steps=1)
print(yhat)
# Out:
# [[ 4.83828788e+00  1.07761794e+03 -2.02755723e+02  1.10508004e+01
#    1.04519077e+03  2.60751060e+02  6.48193186e+02  1.49439100e+02
#    1.15109492e+03  8.46002947e+02  2.60663362e+01  1.44756501e+01
#   -6.35797675e-01]]

# %%
# https://www.analyticsvidhya.com/blog/2018/09/multivariate-time-series-guide-forecasting-modeling-python-codes/?utm_source=DataCamp.com&utm_medium=Community&utm_campaign=News
